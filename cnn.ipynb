# %% [markdown]
# Connected to orchidenv (Python 3.8.18)

# %%
# imports
import numpy as np
from keras import backend as K
K.set_image_data_format('channels_last')
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import cv2
import os
import seaborn as sns

# %%
# paths for training, validation, and testing sets
train_path = '/Users/alextowle/orchids/COM Research Seminar/orchid_data/HERO7 BLACK/train'
valid_path = '/Users/alextowle/orchids/COM Research Seminar/orchid_data/HERO7 BLACK/valid'
test_path = '/Users/alextowle/orchids/COM Research Seminar/orchid_data/HERO7 BLACK/test'

# %%
# method to crop an image
def crop(image):
    h, w, _ = image.shape
    min_dim = min(h, w)
    top = (h - min_dim) // 2
    left = (w - min_dim) // 2
    square_image = image[top:top + min_dim, left:left + min_dim]
    return square_image

# %%
# separate into batches of 3000x4000 size images
train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size = (3000,4000), classes = ['control', 'overhydrated', 'underhydrated'], batch_size = 3, class_mode = 'categorical')
valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size = (3000,4000), classes = ['control', 'overhydrated', 'underhydrated'], batch_size = 48, class_mode = 'categorical')
test_batches = ImageDataGenerator().flow_from_directory(test_path, target_size = (3000,4000), classes = ['control', 'overhydrated', 'underhydrated'], batch_size = 37, class_mode = 'categorical')
# Out:
# Found 1506 images belonging to 3 classes.
# Found 432 images belonging to 3 classes.
# Found 222 images belonging to 3 classes.

# %%
# test to show batch shape
x, y = next(train_batches)
print("Shape of the images batch:", x.shape)
print("Shape of the labels batch:", y.shape)
# Out:
# Shape of the images batch: (3, 3000, 4000, 3)
# Shape of the labels batch: (3, 3)

# %%
# test method to display some sample images
def plots(ims, figsize = (12, 6), rows = 1, interp = False, titles = None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != 3):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize = figsize)
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(len(ims)):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i], interpolation=None if interp else 'none')

# %%
# get the next batch
imgs, labels = next(train_batches)

# %%
# show the batch plots
plots(imgs, titles = labels)

# %%
# method to augment images
# basically you it takes an image, a list of the factors you want to zoom it by,
# and a list of the angles you want it to turn by. It zooms that amount and then makes a version
# of the zoomed image for each angle.
# returns the augmented images
def augment_image(image, zoom_factors, angles):
    image = crop(image)
    image = image.astype(np.uint8)
    augmented_images = [image]
    height, width = image.shape[:2]

    for angle in angles:
        M = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1)
        rotated_img = cv2.warpAffine(image, M, (width, height))

        for zoom in zoom_factors:
            zoomed_img = cv2.resize(rotated_img, None, fx=zoom, fy=zoom, interpolation=cv2.INTER_LINEAR)
            
            start_x = (zoomed_img.shape[1] - width) // 2
            start_y = (zoomed_img.shape[0] - height) // 2
            cropped_img = zoomed_img[start_y:start_y + height, start_x:start_x + width]

            augmented_images.append(cropped_img)

    return augmented_images

# %%
# method to plot the augmented images
def plot_images(images, titles=None, rows=2):
    cols = len(images) // rows if len(images) % rows == 0 else len(images) // rows + 1
    plt.figure(figsize=(15, 10))

    for i in range(len(images)):
        plt.subplot(rows, cols, i+1)

        img = images[i]

        plt.imshow(img)
        plt.axis('off')
        if titles is not None:
            plt.title(titles[i], fontsize=10)
    plt.show()

# %%
#test to show augmentation
zoom_factors = [1.5]
angles = [45, 90, 135, 180, 225, 270, 315]

x_batch, y_batch = next(train_batches)

sample_image = x_batch[0]

augmented_images = augment_image(sample_image, zoom_factors, angles)

plot_images(augmented_images, titles=["Original"] + [f"Zoom {z}, Rotate {a}" for z in zoom_factors for a in [0] + angles])

print(f"Original image min: {sample_image.min()}, max: {sample_image.max()}")

for i, img in enumerate(augmented_images):
    print(f"Augmented image {i} min: {img.min()}, max: {img.max()}")
# Out:
# Original image min: 0.0, max: 255.0
# Augmented image 0 min: 0, max: 255
# Augmented image 1 min: 0, max: 255
# Augmented image 2 min: 0, max: 255
# Augmented image 3 min: 0, max: 255
# Augmented image 4 min: 0, max: 255
# Augmented image 5 min: 0, max: 255
# Augmented image 6 min: 0, max: 255
# Augmented image 7 min: 0, max: 255

# %%
# actual class labels, angles, and zoom factors
class_labels = ['control', 'overhydrated', 'underhydrated']

zoom_factors = [1.5]
angles = [45, 90, 135, 180, 225, 270, 315]

# %%
# method to augment and save all image batches into a new folder
global_image_counter = 0

def augment_and_save_batches(batches, save_dir, steps):
    global global_image_counter
    
    for step in range(steps):
        batch = next(batches)
        images, labels = batch[0], batch[1]
        print(f"Processing batch {step + 1}/{steps}...")

        for i in range(len(images)):
            img = images[i]
            label_index = np.argmax(labels[i])
            label_name = class_labels[label_index]

            augmented_imgs = augment_image(img, zoom_factors, angles)

            for j, aug_img in enumerate(augmented_imgs):
                output_path = os.path.join(save_dir, label_name, f'{label_name}_aug_{global_image_counter}_{i}_{j}.jpg')
                
                global_image_counter += 1
                
                cv2.imwrite(output_path, cv2.cvtColor(aug_img, cv2.COLOR_RGB2BGR))

# %%
# paths where augmented images will be/are saved
train_mod_path = '/Users/alextowle/orchids/COM Research Seminar/orchid_data/HERO7 BLACK/train_mod'
valid_mod_path = '/Users/alextowle/orchids/COM Research Seminar/orchid_data/HERO7 BLACK/valid_mod'
test_mod_path = '/Users/alextowle/orchids/COM Research Seminar/orchid_data/HERO7 BLACK/test_mod'

# %%
# augment and save the batches
# ONLY DO THIS IF
# 1. YOU HAVE NEW IMAGES IN THE NON-MOD FOLDERS THAT NEED TO BE AUGMENTED (DELETE EXISTING DATA IN MOD FOLDERS FIRST)
# OR
# 2. THERE IS NOTHING IN THE MOD FOLDERS TO BEGIN WITH (YOU WILL NEED TO RUN THIS THE FIRST TIME SINCE I DIDN'T HAVE ENOUGH STORAGE TO SEND ALL THE MOD DATA)
# what i do is i clear out the mod folders when new images need to be added and augmented and then rerun this process
# not the most sophisticated approach i know but i had to work with what i did before i knew i needed augmentation
augment_and_save_batches(train_batches, train_mod_path, steps=502)
augment_and_save_batches(valid_batches, valid_mod_path, steps=9)
augment_and_save_batches(test_batches, test_mod_path, steps=6)
# Out:
# Processing batch 1/502...
# Processing batch 2/502...
# Processing batch 3/502...
# Processing batch 4/502...
# Processing batch 5/502...
# Processing batch 6/502...
# Processing batch 7/502...
# Processing batch 8/502...
# Processing batch 9/502...
# Processing batch 10/502...
# Processing batch 11/502...
# Processing batch 12/502...
# Processing batch 13/502...
# Processing batch 14/502...
# Processing batch 15/502...
# Processing batch 16/502...
# Processing batch 17/502...
# Processing batch 18/502...
# Processing batch 19/502...
# Processing batch 20/502...
# Processing batch 21/502...
# Processing batch 22/502...
# Processing batch 23/502...
# Processing batch 24/502...
# Processing batch 25/502...
# Processing batch 26/502...
# Processing batch 27/502...
# Processing batch 28/502...
# Processing batch 29/502...
# Processing batch 30/502...
# Processing batch 31/502...
# Processing batch 32/502...
# Processing batch 33/502...
# Processing batch 34/502...
# Processing batch 35/502...
# Processing batch 36/502...
# Processing batch 37/502...
# Processing batch 38/502...
# Processing batch 39/502...
# Processing batch 40/502...
# Processing batch 41/502...
# Processing batch 42/502...
# Processing batch 43/502...
# Processing batch 44/502...
# Processing batch 45/502...
# Processing batch 46/502...
# Processing batch 47/502...
# Processing batch 48/502...
# Processing batch 49/502...
# Processing batch 50/502...
# Processing batch 51/502...
# Processing batch 52/502...
# Processing batch 53/502...
# Processing batch 54/502...
# Processing batch 55/502...
# Processing batch 56/502...
# Processing batch 57/502...
# Processing batch 58/502...
# Processing batch 59/502...
# Processing batch 60/502...
# Processing batch 61/502...
# Processing batch 62/502...
# Processing batch 63/502...
# Processing batch 64/502...
# Processing batch 65/502...
# Processing batch 66/502...
# Processing batch 67/502...
# Processing batch 68/502...
# Processing batch 69/502...
# Processing batch 70/502...
# Processing batch 71/502...
# Processing batch 72/502...
# Processing batch 73/502...
# Processing batch 74/502...
# Processing batch 75/502...
# Processing batch 76/502...
# Processing batch 77/502...
# Processing batch 78/502...
# Processing batch 79/502...
# Processing batch 80/502...
# Processing batch 81/502...
# Processing batch 82/502...
# Processing batch 83/502...
# Processing batch 84/502...
# Processing batch 85/502...
# Processing batch 86/502...
# Processing batch 87/502...
# Processing batch 88/502...
# Processing batch 89/502...
# Processing batch 90/502...
# Processing batch 91/502...
# Processing batch 92/502...
# Processing batch 93/502...
# Processing batch 94/502...
# Processing batch 95/502...
# Processing batch 96/502...
# Processing batch 97/502...
# Processing batch 98/502...
# Processing batch 99/502...
# Processing batch 100/502...
# Processing batch 101/502...
# Processing batch 102/502...
# Processing batch 103/502...
# Processing batch 104/502...
# Processing batch 105/502...
# Processing batch 106/502...
# Processing batch 107/502...
# Processing batch 108/502...
# Processing batch 109/502...
# Processing batch 110/502...
# Processing batch 111/502...
# Processing batch 112/502...
# Processing batch 113/502...
# Processing batch 114/502...
# Processing batch 115/502...
# Processing batch 116/502...
# Processing batch 117/502...
# Processing batch 118/502...
# Processing batch 119/502...
# Processing batch 120/502...
# Processing batch 121/502...
# Processing batch 122/502...
# Processing batch 123/502...
# Processing batch 124/502...
# Processing batch 125/502...
# Processing batch 126/502...
# Processing batch 127/502...
# Processing batch 128/502...
# Processing batch 129/502...
# Processing batch 130/502...
# Processing batch 131/502...
# Processing batch 132/502...
# Processing batch 133/502...
# Processing batch 134/502...
# Processing batch 135/502...
# Processing batch 136/502...
# Processing batch 137/502...
# Processing batch 138/502...
# Processing batch 139/502...
# Processing batch 140/502...
# Processing batch 141/502...
# Processing batch 142/502...
# Processing batch 143/502...
# Processing batch 144/502...
# Processing batch 145/502...
# Processing batch 146/502...
# Processing batch 147/502...
# Processing batch 148/502...
# Processing batch 149/502...
# Processing batch 150/502...
# Processing batch 151/502...
# Processing batch 152/502...
# Processing batch 153/502...
# Processing batch 154/502...
# Processing batch 155/502...
# Processing batch 156/502...
# Processing batch 157/502...
# Processing batch 158/502...
# Processing batch 159/502...
# Processing batch 160/502...
# Processing batch 161/502...
# Processing batch 162/502...
# Processing batch 163/502...
# Processing batch 164/502...
# Processing batch 165/502...
# Processing batch 166/502...
# Processing batch 167/502...
# Processing batch 168/502...
# Processing batch 169/502...
# Processing batch 170/502...
# Processing batch 171/502...
# Processing batch 172/502...
# Processing batch 173/502...
# Processing batch 174/502...
# Processing batch 175/502...
# Processing batch 176/502...
# Processing batch 177/502...
# Processing batch 178/502...
# Processing batch 179/502...
# Processing batch 180/502...
# Processing batch 181/502...
# Processing batch 182/502...
# Processing batch 183/502...
# Processing batch 184/502...
# Processing batch 185/502...
# Processing batch 186/502...
# Processing batch 187/502...
# Processing batch 188/502...
# Processing batch 189/502...
# Processing batch 190/502...
# Processing batch 191/502...
# Processing batch 192/502...
# Processing batch 193/502...
# Processing batch 194/502...
# Processing batch 195/502...
# Processing batch 196/502...
# Processing batch 197/502...
# Processing batch 198/502...
# Processing batch 199/502...
# Processing batch 200/502...
# Processing batch 201/502...
# Processing batch 202/502...
# Processing batch 203/502...
# Processing batch 204/502...
# Processing batch 205/502...
# Processing batch 206/502...
# Processing batch 207/502...
# Processing batch 208/502...
# Processing batch 209/502...
# Processing batch 210/502...
# Processing batch 211/502...
# Processing batch 212/502...
# Processing batch 213/502...
# Processing batch 214/502...
# Processing batch 215/502...
# Processing batch 216/502...
# Processing batch 217/502...
# Processing batch 218/502...
# Processing batch 219/502...
# Processing batch 220/502...
# Processing batch 221/502...
# Processing batch 222/502...
# Processing batch 223/502...
# Processing batch 224/502...
# Processing batch 225/502...
# Processing batch 226/502...
# Processing batch 227/502...
# Processing batch 228/502...
# Processing batch 229/502...
# Processing batch 230/502...
# Processing batch 231/502...
# Processing batch 232/502...
# Processing batch 233/502...
# Processing batch 234/502...
# Processing batch 235/502...
# Processing batch 236/502...
# Processing batch 237/502...
# Processing batch 238/502...
# Processing batch 239/502...
# Processing batch 240/502...
# Processing batch 241/502...
# Processing batch 242/502...
# Processing batch 243/502...
# Processing batch 244/502...
# Processing batch 245/502...
# Processing batch 246/502...
# Processing batch 247/502...
# Processing batch 248/502...
# Processing batch 249/502...
# Processing batch 250/502...
# Processing batch 251/502...
# Processing batch 252/502...
# Processing batch 253/502...
# Processing batch 254/502...
# Processing batch 255/502...
# Processing batch 256/502...
# Processing batch 257/502...
# Processing batch 258/502...
# Processing batch 259/502...
# Processing batch 260/502...
# Processing batch 261/502...
# Processing batch 262/502...
# Processing batch 263/502...
# Processing batch 264/502...
# Processing batch 265/502...
# Processing batch 266/502...
# Processing batch 267/502...
# Processing batch 268/502...
# Processing batch 269/502...
# Processing batch 270/502...
# Processing batch 271/502...
# Processing batch 272/502...
# Processing batch 273/502...
# Processing batch 274/502...
# Processing batch 275/502...
# Processing batch 276/502...
# Processing batch 277/502...
# Processing batch 278/502...
# Processing batch 279/502...
# Processing batch 280/502...
# Processing batch 281/502...
# Processing batch 282/502...
# Processing batch 283/502...
# Processing batch 284/502...
# Processing batch 285/502...
# Processing batch 286/502...
# Processing batch 287/502...
# Processing batch 288/502...
# Processing batch 289/502...
# Processing batch 290/502...
# Processing batch 291/502...
# Processing batch 292/502...
# Processing batch 293/502...
# Processing batch 294/502...
# Processing batch 295/502...
# Processing batch 296/502...
# Processing batch 297/502...
# Processing batch 298/502...
# Processing batch 299/502...
# Processing batch 300/502...
# Processing batch 301/502...
# Processing batch 302/502...
# Processing batch 303/502...
# Processing batch 304/502...
# Processing batch 305/502...
# Processing batch 306/502...
# Processing batch 307/502...
# Processing batch 308/502...
# Processing batch 309/502...
# Processing batch 310/502...
# Processing batch 311/502...
# Processing batch 312/502...
# Processing batch 313/502...
# Processing batch 314/502...
# Processing batch 315/502...
# Processing batch 316/502...
# Processing batch 317/502...
# Processing batch 318/502...
# Processing batch 319/502...
# Processing batch 320/502...
# Processing batch 321/502...
# Processing batch 322/502...
# Processing batch 323/502...
# Processing batch 324/502...
# Processing batch 325/502...
# Processing batch 326/502...
# Processing batch 327/502...
# Processing batch 328/502...
# Processing batch 329/502...
# Processing batch 330/502...
# Processing batch 331/502...
# Processing batch 332/502...
# Processing batch 333/502...
# Processing batch 334/502...
# Processing batch 335/502...
# Processing batch 336/502...
# Processing batch 337/502...
# Processing batch 338/502...
# Processing batch 339/502...
# Processing batch 340/502...
# Processing batch 341/502...
# Processing batch 342/502...
# Processing batch 343/502...
# Processing batch 344/502...
# Processing batch 345/502...
# Processing batch 346/502...
# Processing batch 347/502...
# Processing batch 348/502...
# Processing batch 349/502...
# Processing batch 350/502...
# Processing batch 351/502...
# Processing batch 352/502...
# Processing batch 353/502...
# Processing batch 354/502...
# Processing batch 355/502...
# Processing batch 356/502...
# Processing batch 357/502...
# Processing batch 358/502...
# Processing batch 359/502...
# Processing batch 360/502...
# Processing batch 361/502...
# Processing batch 362/502...
# Processing batch 363/502...
# Processing batch 364/502...
# Processing batch 365/502...
# Processing batch 366/502...
# Processing batch 367/502...
# Processing batch 368/502...
# Processing batch 369/502...
# Processing batch 370/502...
# Processing batch 371/502...
# Processing batch 372/502...
# Processing batch 373/502...
# Processing batch 374/502...
# Processing batch 375/502...
# Processing batch 376/502...
# Processing batch 377/502...
# Processing batch 378/502...
# Processing batch 379/502...
# Processing batch 380/502...
# Processing batch 381/502...
# Processing batch 382/502...
# Processing batch 383/502...
# Processing batch 384/502...
# Processing batch 385/502...
# Processing batch 386/502...
# Processing batch 387/502...
# Processing batch 388/502...
# Processing batch 389/502...
# Processing batch 390/502...
# Processing batch 391/502...
# Processing batch 392/502...
# Processing batch 393/502...
# Processing batch 394/502...
# Processing batch 395/502...
# Processing batch 396/502...
# Processing batch 397/502...
# Processing batch 398/502...
# Processing batch 399/502...
# Processing batch 400/502...
# Processing batch 401/502...
# Processing batch 402/502...
# Processing batch 403/502...
# Processing batch 404/502...
# Processing batch 405/502...
# Processing batch 406/502...
# Processing batch 407/502...
# Processing batch 408/502...
# Processing batch 409/502...
# Processing batch 410/502...
# Processing batch 411/502...
# Processing batch 412/502...
# Processing batch 413/502...
# Processing batch 414/502...
# Processing batch 415/502...
# Processing batch 416/502...
# Processing batch 417/502...
# Processing batch 418/502...
# Processing batch 419/502...
# Processing batch 420/502...
# Processing batch 421/502...
# Processing batch 422/502...
# Processing batch 423/502...
# Processing batch 424/502...
# Processing batch 425/502...
# Processing batch 426/502...
# Processing batch 427/502...
# Processing batch 428/502...
# Processing batch 429/502...
# Processing batch 430/502...
# Processing batch 431/502...
# Processing batch 432/502...
# Processing batch 433/502...
# Processing batch 434/502...
# Processing batch 435/502...
# Processing batch 436/502...
# Processing batch 437/502...
# Processing batch 438/502...
# Processing batch 439/502...
# Processing batch 440/502...
# Processing batch 441/502...
# Processing batch 442/502...
# Processing batch 443/502...
# Processing batch 444/502...
# Processing batch 445/502...
# Processing batch 446/502...
# Processing batch 447/502...
# Processing batch 448/502...
# Processing batch 449/502...
# Processing batch 450/502...
# Processing batch 451/502...
# Processing batch 452/502...
# Processing batch 453/502...
# Processing batch 454/502...
# Processing batch 455/502...
# Processing batch 456/502...
# Processing batch 457/502...
# Processing batch 458/502...
# Processing batch 459/502...
# Processing batch 460/502...
# Processing batch 461/502...
# Processing batch 462/502...
# Processing batch 463/502...
# Processing batch 464/502...
# Processing batch 465/502...
# Processing batch 466/502...
# Processing batch 467/502...
# Processing batch 468/502...
# Processing batch 469/502...
# Processing batch 470/502...
# Processing batch 471/502...
# Processing batch 472/502...
# Processing batch 473/502...
# Processing batch 474/502...
# Processing batch 475/502...
# Processing batch 476/502...
# Processing batch 477/502...
# Processing batch 478/502...
# Processing batch 479/502...
# Processing batch 480/502...
# Processing batch 481/502...
# Processing batch 482/502...
# Processing batch 483/502...
# Processing batch 484/502...
# Processing batch 485/502...
# Processing batch 486/502...
# Processing batch 487/502...
# Processing batch 488/502...
# Processing batch 489/502...
# Processing batch 490/502...
# Processing batch 491/502...
# Processing batch 492/502...
# Processing batch 493/502...
# Processing batch 494/502...
# Processing batch 495/502...
# Processing batch 496/502...
# Processing batch 497/502...
# Processing batch 498/502...
# Processing batch 499/502...
# Processing batch 500/502...
# Processing batch 501/502...
# Processing batch 502/502...
# Processing batch 1/9...
# Processing batch 2/9...
# Processing batch 3/9...
# Processing batch 4/9...
# Processing batch 5/9...
# Processing batch 6/9...
# Processing batch 7/9...
# Processing batch 8/9...
# Processing batch 9/9...
# Processing batch 1/6...
# Processing batch 2/6...
# Processing batch 3/6...
# Processing batch 4/6...
# Processing batch 5/6...
# Processing batch 6/6...

# %%
# creating the mod batches
# i downsized these resolutions for training time purposes.
# playing with the resolution isn't something i had much time to experiment with but could be useful.
train_mod_batches = ImageDataGenerator(
    preprocessing_function=lambda x: x / 255.0
).flow_from_directory(
    train_mod_path,
    target_size=(224, 224),
    batch_size=6,
    class_mode='categorical'
)

valid_mod_batches = ImageDataGenerator(
    preprocessing_function=lambda x: x / 255.0
).flow_from_directory(
    valid_mod_path,
    target_size=(224, 224),
    batch_size=96,
    class_mode='categorical'
)
test_mod_batches = ImageDataGenerator(
    preprocessing_function=lambda x: x / 255.0
).flow_from_directory(
    test_mod_path, 
    target_size = (224,224), 
    batch_size = 74, 
    class_mode = 'categorical'
    )
# Out:
# Found 12048 images belonging to 3 classes.
# Found 3456 images belonging to 3 classes.
# Found 1776 images belonging to 3 classes.

# %%
# building the cnn
# I started very simple a while back and gradually added all of these layers. it showed no significant improvement from the basic model.
# it does better than guessing but it usually is around high 50% to low 60% for accuracy (guessing is 33%)
# i pivoted to the vit which generally performs better (getting low 70% range usually) but it may still be worth playing around with this architecture.
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3), data_format='channels_last'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(3, activation = 'softmax'),
])
# Out:
# /Users/alextowle/anaconda3/envs/orchidenv/lib/python3.9/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# compiling the cnn model
model.compile(Adam(learning_rate=.0001), loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
# takes python generator and makes a tensorflow dataset object from it
# (cnn and vit can be picky about which one is used so i left both in because i was frequently changing approaches that needed one or the other)
def generator_to_tf_dataset(generator, batch_size):
    output_signature = (
        tf.TensorSpec(shape=(batch_size, 224, 224, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(batch_size, 3), dtype=tf.float32)
    )
    dataset = tf.data.Dataset.from_generator(
        lambda: generator,
        output_signature=output_signature
    )
    dataset = dataset.repeat()
    return dataset

# %%
# create the tensorflow datasets
train_tf_dataset = generator_to_tf_dataset(train_mod_batches, batch_size=6)
valid_tf_dataset = generator_to_tf_dataset(valid_mod_batches, batch_size=96)
test_tf_dataset = generator_to_tf_dataset(test_mod_batches, batch_size=74)

# %%
# calculates the proper steps per epoch based on the batch size
train_steps = train_mod_batches.n // train_mod_batches.batch_size
valid_steps = valid_mod_batches.n // valid_mod_batches.batch_size

# train the model
history = model.fit(
    x=train_tf_dataset,
    steps_per_epoch=train_steps,
    validation_data=valid_tf_dataset,
    validation_steps=valid_steps,
    epochs=20,
    verbose=2
)
# Out:
# Epoch 1/4
# 2008/2008 - 1276s - 636ms/step - accuracy: 0.4788 - loss: 1.0143 - val_accuracy: 0.5408 - val_loss: 0.9599
# Epoch 2/4
# 2008/2008 - 1298s - 646ms/step - accuracy: 0.5969 - loss: 0.8649 - val_accuracy: 0.6146 - val_loss: 0.8559
# Epoch 3/4
# 2008/2008 - 1229s - 612ms/step - accuracy: 0.7037 - loss: 0.6674 - val_accuracy: 0.6808 - val_loss: 0.7491
# Epoch 4/4
# 2008/2008 - 1260s - 627ms/step - accuracy: 0.7982 - loss: 0.4986 - val_accuracy: 0.6901 - val_loss: 0.7582

# %%
# plotting accuracy in the history
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# plotting loss in the history
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# lists for predictions and true labels
all_predictions = []
all_true_labels = []

# make predictions for every image in each test batch
for batch_images, batch_labels in test_tf_dataset:
    # apply model to predict test images
    predictions = model.predict(batch_images)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = np.argmax(batch_labels, axis=1)

    all_predictions.extend(predicted_classes)
    all_true_labels.extend(true_classes)

    if len(all_true_labels) >= test_mod_batches.n:
        break

# make the confusion matrix
cm = confusion_matrix(all_true_labels, all_predictions)
class_names = list(test_mod_batches.class_indices.keys())

# plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# classification report
report = classification_report(all_true_labels, all_predictions, target_names=class_names)
print("Classification Report:")
print(report)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       control       0.61      0.71      0.65       616
#  overhydrated       0.72      0.56      0.63       568
# underhydrated       0.74      0.77      0.76       592
#
#      accuracy                           0.68      1776
#     macro avg       0.69      0.68      0.68      1776
#  weighted avg       0.69      0.68      0.68      1776
